# %%
// 자바스크립트
// setTimeout(함수, 밀리초) 밀리초 후에 콜백함수 실행. 단발성
// setInterval(함수, 밀리초) 밀리초 마다 콜백함수 실행. 반복 
function hello() {
    console.log('hello')
}
setTimeout(hello, 1000)

//pip3 install --upgrade pip
// pip3 install jupyter
// npm install -g ijavascript
// ijsinstall

# %% [markdown]
# ![image.png](attachment:image.png)
