# %% [markdown]
# # 머신러닝 machine learning :
# - 학습이라는 능력을 컴퓨터로 구현하는 방법
# - 많은 데이터를 학습시켜 패턴을 찾아내 패턴을 기반으로 예측 하는것
# - 인공지능 연구과제 중 하나
# - 인간의 뇌가 자연스럽게 수행하는 '학습' 이라는 능력을 컴퓨터로  구현하는 방법
#     1. 대규모 샘플 데이터 분석
#     2. 규칙을 찾아냄
#     3. 규칙을 기반으로 다른 데이터 분류 및 예측 (인공지능 = 분류 및 예측)
#
# - 벡터 vector : 공간에서 크기와 방향을 가진다
# - 특징량 : 어떤 요소가 모여있는 것
#
# ## 예상 시나리오
# 0. 데이터 수집
# 1. 데이터를 좌표에 찍는다 (데이터 가공)
# 2. x 최소 최대 y 최소 최대 를 기준으로 이미지 크기를 결정한다
# 3. 이미지의 크기를 축소하고 패턴크기로 정형화 한다 (비지도학습)
# 4. 이미지를 분석하여 어떤 군집을 이루는지 가려낸다
# 5. 가려낸 패턴을 토대로 데이터를 정의 한다. (지도학습)
#
# ## 이미지 분석 시나리오
# 1. 특징을 찾아낸다.
# 2. 특징을 가려낸다.
# 3. 특징을 비교한다.
# 4. 특징이 맞는지 확정한다.

# %% [markdown]
# ### 모두의 딥러닝
# - LLM
# - 멀티모달
# - 전처리
# - 모델
# - EDM
# - 시각화 : 분석방법 찾기
# - 치트 시트
# - 은닉층
# - CNN : Convolutional Neural Network 합성곱, 주로 이미지 데이터 처리를 위해 설계된 신경망 ,
# - RNN : Recurrent Neural Network 재귀, 시계열 데이터나 순차 데이터를 처리하기 위해 설계된 신경망
# - GAN : Generative Adversarial Network 생성 모델의 일종으로, 두 개의 네트워크(생성자와 판별자)가 상호 경쟁하면서 학습하는 구조를 가지고 있습니다.
# - 지도 학습 :
# - 비지도 학습 :
# - 머신러닝 : task 작업, 성능, data  (데이터에서 반복적으로 학습하여 성능을 향상시키며, 특정 작업을 자동화하고 예측하는 데 사용) TPE
# - 기계학습 : 통계적 학습, 지도학습, 분류, label작업
# - 통계학 :
# - 데이터 마이닝 : 트레이닝데이터 , 특징추출, 시각화, 분류,
# - 예측 prediction, 군집 clustering, 분류 classification, 연관규칙 association rule
# - 정규분포 가우스분포 종모양

# %% [markdown]
# ### 전처리
# - 표준화 : z변환 , 정규화(0-1변환)
# - 정규분포화 : 로그변환, 제곱근변환
# - 범주화 : 이산형화, 이항변수화
# - 개수 축소 : 랜덤표본화, 체계적추출, 층화 임의 추출, 군집추출, 다단계 추출
# - 차원 축소 : 요인분석, 주성분 분석
# - 시그널 데이터 압축
#
# ### 데이터 : 훈련데이터, 타당성검증 데이터, 시험데이터

# %% [markdown]
# - 답이 있으면 지도 학습.
# - root mean squared error : 오차의 제곱의 합의 제곱근
