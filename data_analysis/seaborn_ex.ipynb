# %% [markdown]
# # seaborn
# - 고급 시각화

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib
import numpy as np
matplotlib.rc('font', family='gulim') # NanumGothic  gulim NanumSquareRoundR

# %%
path = r'https://github.com/taehojo/deeplearning/raw/master/data/pima-indians-diabetes3.csv'
df = pd.read_csv(path, header=None)
df.columns = df.iloc[0]
df = df.iloc[1:, :]
# df = df.iloc[1:, :].astype('float')
# pregnant	plasma	pressure	thickness	insulin	bmi	pedigree	age	diabetes
df['pregnant'] = df['pregnant'].astype('int')
df['plasma'] = df['plasma'].astype('int')
df['pressure'] = df['pressure'].astype('int')
df['thickness'] = df['thickness'].astype('int')
df['insulin'] = df['insulin'].astype('int')
df['bmi'] = df['bmi'].astype('float')
df['pedigree'] = df['pedigree'].astype('float')
df['age'] = df['age'].astype('int')
df['diabetes'] = df['diabetes'].astype('int')
x_train = df.iloc[:, 0:8]
y_train = df['diabetes']

# %%
# help(sns.heatmap)
sns.heatmap(df.corr(), cmap=plt.get_cmap(), annot=True)
plt.get_cmap()

# %%
# sns.histplot(df['plasma'])
# sns.histplot(df['diabetes'])
# sns.histplot(df[['plasma', 'bmi']][df['diabetes'] == 1])
# sns.histplot(df[['plasma', 'bmi']][df['diabetes'] == 0])
sns.histplot(df['plasma'][df['diabetes'] == 1])
sns.histplot(df['plasma'][df['diabetes'] == 0])
plt.show()

# %%
sns.histplot(df['bmi'][df['diabetes'] == 1])
sns.histplot(df['bmi'][df['diabetes'] == 0])
plt.show()

# %%
sns.histplot(df['age'][df['diabetes'] == 1])
sns.histplot(df['age'][df['diabetes'] == 0])
plt.show()

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# 예시로 첫 번째 폰트 경로 출력
print("첫 번째 폰트 경로:", font_list[0])

# 특정 폰트 불러오기
font_path = font_list[0]  # 첫 번째 폰트를 예시로 사용
font_prop = fm.FontProperties(fname = r'C:/Windows/Fonts/NanumGothic.ttf')
for i in font_list:
    if 'num' in i:
        print(i, type(i))
# Out:
# 첫 번째 폰트 경로: C:\Windows\Fonts\MAIAN.TTF
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundL.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundEB.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumGothicExtraBold.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundR.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumGothicLight.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundB.ttf <class 'str'>
# C:\Users\hungh\AppData\Local\Microsoft\Windows\Fonts\NanumGothic.ttf <class 'str'>

# %%
xarr = np.random.randn(10000) * 10  +3
plt.hist(xarr, density=True) # density : count가 아닌 확률로 바뀜
plt.show()

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.font_manager._rebuild()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 import matplotlib as mpl
#       2 import matplotlib.font_manager as fm
# ----> 3 mpl.font_manager._rebuild()
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'

# %%
data = pd.DataFrame({'x':['1분기', '2분기', '3분기', '4분기'], 'y': [200, 300, 100, 400]})
# import matplotlib.pyplot as plt

plt.rc('font',family='NanumSquareRoundR')
# plt.rcParams['font.family'] = 'gulim'
print(plt.rcParams['font.family'])
plt.bar(data['x'], data['y'])

plt.show()
# Out:
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# findfont: Font family 'NanumSquareRoundR' not found.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('titanic')
sns.countplot(x='pclass', data=data, hue='alive')
# sns.histplot(x='pclass', data=data, hue='alive')
# sns.barplot(x='pclass', data=data, hue='alive')
# sns.boxplot(x='pclass', data=data, hue='alive')

plt.show()
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
