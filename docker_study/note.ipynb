# %% [markdown]
# # DOCKER
# ##

# %% [markdown]
# - https://www.docker.com/
# - https://hub.docker.com/

# %% [markdown]
# - 윈도우에 설치
# > ![image.png](attachment:image.png)
# - 설정에서 windows 기능 켜기/끄기 실행
# > ![image-2.png](attachment:image-2.png)
# >
# > ![image-3.png](attachment:image-3.png)
# - Hyper-V 기능 체크 하기, linux용 windows 하위 시스템 체크 하기

# %% [markdown]
# - https://learn.microsoft.com/ko-kr/windows/wsl/tutorials/gui-apps
# - gui 되게 하고 크롬까지
# - https://digiconfactory.tistory.com/entry/WSL2-%EC%9A%B0%EB%B6%84%ED%88%AC-%EB%A6%AC%EB%88%85%EC%8A%A4-%ED%95%9C%EA%B8%80-%EC%9E%85%EB%A0%A5%EA%B8%B0
